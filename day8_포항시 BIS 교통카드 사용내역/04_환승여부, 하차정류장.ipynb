# %%
import pandas as pd

# %%
df = pd.read_csv('./data/df_new_final.csv')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  노선명                   노선설명 승객연령 환승여부 추가운임여부  \
# 0                  0           0  500      문덕-시외터미널-흥해-청하-월포   일반    N      N
# 1                  1           1  101            양덕-고속터미널-동해   일반    N      N
# 2                  2           2  131         양덕-송도-시청-양학-양덕   일반    N      N
# 3                  3           3  101            양덕-고속터미널-동해   일반    N      N
# 4                  4           4  108      양덕-죽도-양학-시청-유강-지곡   일반    N      N
# ...              ...         ...  ...                    ...  ...  ...    ...
# 841678        841678      841678  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    Y      N
# 841679        841679      841679  200        양덕-남구청(야구장)-구룡포   일반    N      N
# 841680        841680      841680  500      문덕-시외터미널-흥해-청하-월포   일반    N      N
# 841681        841681      841681  107        문덕-시외(고속)터미널-흥해   일반    N      N
# 841682        841682      841682  108      양덕-죽도-양학-시청-유강-지곡   일반    N      N
#
# ...

# %%
a = df['하차정류장'].value_counts().sort_values(ascending=False).head(300)
a.reset_index()
# Out:
#         index   하차정류장
# 0        죽도시장  139443
# 1     시외버스터미널   78072
# 2        중앙상가   44182
# 3         북구청   19735
# 4        홈플러스   18237
# ..        ...     ...
# 295        고현     168
# 296      전자여고     168
# 297  경북교육청문화원     165
# 298      한일철강     164
# 299    수협호미곶점     159
#
# [300 rows x 2 columns]

# %%
b = df[df['환승여부'] == 'Y']['승차정류장'].value_counts().sort_values(ascending=False).head(300)
b.reset_index()
# Out:
#        index  승차정류장
# 0       죽도시장  11006
# 1    시외버스터미널   7417
# 2       중앙상가   3237
# 3      남구보건소   3208
# 4    구룡포환승센터   1936
# ..       ...    ...
# 295    장기파출소      2
# 296    효자아트홀      2
# 297    신흥중학교      2
# 298  삼도미래1단지      2
# 299      문덕교      2
#
# [300 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(a, b)
